# %% [markdown]
# # What is Seaborn?
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# # How Seaborn Library is Different from Matplotlib Library?
#
# Seaborn is great for quickly creating visually appealing plots with minimal code, while Matplotlib offers more customization options and fine-grained control over every aspect of a plot. Ultimately, the choice between Seaborn and Matplotlib will depend on the specific requirements of your project.
#
# # What are the different types  covered  in Seaborn?
# 1)Line Plot
# 2)Bar Plot
# 3)Histogram
# 4)Scatter Plot
# 5)Heatmap
# 6)Countplot
# 7)Violin Plot
# 8)Pairplot
# 9)Strip Plot
# 10)Box Plot
# 11)Categorical Plot/Cat Plot
# 12)Color Palletes
# 13)Multiple Plots
# 14)Relational Plots
# 15)Swarm Plot
# 16)KDE Plot (Kernel Density Estimation)

# %% [markdown]
# # Dataset Links:
# 1)This dataset is the inbulit dataset used in  Seaborn Library:
# https://github.com/mwaskom/seaborn-data
#
# 2)This dataset is my dataset provided into Github:
# https://github.com/tech-dheer-98

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1) Line Graph:
# Line graphs are a type of chart that shows how a value changes over time or in relation to another variable.
#
# ###  Used for:
# Typically, we use line plots when we have a smaller set of values to display.

# %%
# Importing the Dataset 

emp=pd.read_excel("ESD.xlsx")
emp.head(2)
# Out:
#      EEID      Full Name            Job Title Department  \
# 0  E02387    Emily Davis           Sr. Manger         IT
# 1  E04105  Theodore Dinh  Technical Architect         IT
#
#             Business Unit  Gender Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female     Black   55 2016-04-08         141604
# 1           Manufacturing    Male     Asian   59 1997-11-29          99975
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# 1     0.00          China  Chongqing        NaT

# %%
# Reading all columns
emp.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary', 'Bonus %',
#        'Country', 'City', 'Exit Date'],
#       dtype='object')

# %%
emp['Business Unit'].value_counts()
# Out:
# Manufacturing             269
# Speciality Products       265
# Corporate                 237
# Research & Development    229
# Name: Business Unit, dtype: int64

# %%
# Plotting the Line Graphs based on Gender and Ethnicity
plt.figure(figsize=(14,8),dpi=100)

plt.subplot(2,2,1)
sns.lineplot(data=emp,x=emp['Business Unit'],y=emp.Age,hue='Gender')

plt.subplot(2,2,2)
sns.lineplot(data=emp,x=emp['Business Unit'],y=emp.Age,hue='Ethnicity')

plt.show()

# %% [markdown]
# # Visual Insights :
# 1) Graph 1: This depicts the age categories based on gender, distinguishing between males and females.
# 2) Graph 2: This illustrates the age categories based on ethnicity.

# %% [markdown]
# # 2) Bar Plot:
# A bar plot, also known as a bar chart, is a type of graph that shows the relationship between a categorical and numeric variable. The bars can be plotted vertically or horizontally. A vertical bar chart is sometimes called a column chart.
#
# # Used for :
# A bar chart is used when you want to show a distribution of data points or perform a comparison of metric values across different subgroups of your data.

# %%
# Importing the Dataset:

data=sns.load_dataset("tips")
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Plotting the Bar Graph 

sns.barplot(data=data,x="day",y="total_bill",estimator="sum",hue="sex",palette='bright',order=["Sun","Sat","Fri","Thur"])
plt.show()
#estimator=Sum,Mean,Median
#hue= Grouping the values.
#order=Arranging the values as per choise , for which we are plotting (x-axis)
#palette=It is the list of color code we want to give Eg(Blues,spring,etc)..for more refer the seaborn color documentation.

# %% [markdown]
# # Visual Insights :
# Based on the graph above, it can be concluded that males spend more than females in restaurants, with the highest expenditures occurring on Saturdays and Sundays.

# %% [markdown]
# # 3) Histogram Plot :
# A histogram is a graph showing frequency distributions.
#
# # Used for :
# To check the frequency  of any dataset.

# %%
# Importing the inbuit datasets of Seaborn Library:
# Example1:
data=sns.load_dataset("tips")
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Plotting the Histogram Graph :

sns.histplot(data=data,x="smoker",kde=True,color='orange')
plt.title("Comparison of Smokers vs Non-Smokers")

# kde=It will Distribution of the graph

plt.show()

# %% [markdown]
# # Visual Inisight:
# From the above bar graph we can conclude that the count of Non-Smoker is greater then Smoker .

# %%
# Importing the dataset 
df=sns.load_dataset("titanic")
df.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
# Plotting the histogram Graph

plt.title("Age group of People in the Titanic Ship")
sns.histplot(data=df,x="age",kde=True,hue="who")

plt.show()

# %% [markdown]
# # Visual Insights:
#
# 1)Count of Age group of Child between 0-5 years , is highesh
# 2)Count of Age Group of Women between 20-25years , is highest
# 3)Count of Age Group of Men between 15-35years ,is highest

# %% [markdown]
# # 4) Scatter Plot:
# A scatter plot is a diagram where each value in the data set is represented by a dot.
# It is created by plotting the values of one variable on the x-axis and the values of the other variable on the y-axis. Each point on the plot represents a single data point.
#
# # Used for:
# Scatter plots' primary uses are to observe and show relationships between 2 numeric variables.

# %%
# Importing the Dataset:
df=sns.load_dataset("tips")
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
#Plotting the Scatter Plot 

plt.figure(figsize=(8,10))
plt.suptitle("Tips Analysis",size=30,color='green')
plt.subplot(2,2,1)
sns.scatterplot(data=df,x='total_bill',y='tip',hue='time',marker="o",palette='deep')

plt.subplot(2,2,2)
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex',marker="o",palette='deep')


plt.subplot(2,2,3)
sns.scatterplot(data=df,x='total_bill',y='tip',hue='smoker',marker="o",palette='deep')



plt.show()

# %% [markdown]
# # Visual Insights:
# 1) Graph1: We conclude from this Scatter chart that ,Maximum Tips received was during dinner time.
# 2) Garph2: We conclude from this Scatter chart that , Maximum Tips received was from Males.
# 3) Graph3: We conclude from this Scatter chart that, Maximum Tips received was from Non-Smokers.

# %% [markdown]
# # 5) Heat Map :
# A heatmap is a graphical representation of data where the individual values contained in a matrix are represented as colors
#
# # Used for :
# Heatmaps are a powerful tool for visualizing data. They can be used to identify patterns and trends in data, and to compare different datasets.

# %%
# Importing the Dataset:

data=sns.load_dataset("tips")
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Method 1 
gb=data.groupby("day")["tip"].mean()
gb
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
# Method 2: using the Aggregate Function 
agb=data.groupby("day").agg({"tip":"mean"})
agb
# Out:
#            tip
# day
# Thur  2.771452
# Fri   2.734737
# Sat   2.993103
# Sun   3.255132

# %%
# Sorting the values into descending order: 
agb_sort=agb.sort_values("tip",ascending=False)
agb_sort
# Out:
#            tip
# day
# Sun   3.255132
# Sat   2.993103
# Thur  2.771452
# Fri   2.734737

# %%
# Plotting the Heatmap

sns.heatmap(data=agb_sort)

plt.show()

# %% [markdown]
# # Visual Inisghts :
# From the above Heatmap we can conclude that Darker the color , lesser the tip received .

# %%
# Example 2: Taking the Employee Dataset 

emp.head(2)
# Out:
#      EEID      Full Name            Job Title Department  \
# 0  E02387    Emily Davis           Sr. Manger         IT
# 1  E04105  Theodore Dinh  Technical Architect         IT
#
#             Business Unit  Gender Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female     Black   55 2016-04-08         141604
# 1           Manufacturing    Male     Asian   59 1997-11-29          99975
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# 1     0.00          China  Chongqing        NaT

# %%
# Using the Aggregate Function 
egb=emp.groupby("Business Unit").agg({"Annual Salary":"mean"})
egb
# Out:
#                         Annual Salary
# Business Unit
# Corporate               120776.151899
# Manufacturing           103651.371747
# Research & Development  112490.205240
# Speciality Products     116796.003774

# %%
#Sorting the values in descending order:
egb_sorted=egb.sort_values("Annual Salary",ascending=False)
egb_sorted
# Out:
#                         Annual Salary
# Business Unit
# Corporate               120776.151899
# Speciality Products     116796.003774
# Research & Development  112490.205240
# Manufacturing           103651.371747

# %%
# Plotting the Heatmap for the given value:

sns.heatmap(egb_sorted)

plt.show()

# %% [markdown]
# # Visual Insights:
# From the above Heatmap we can conclude that  Corporate Department receivess the Highest Salary, whereas Manufacturing Department received the lowest Salary.

# %% [markdown]
# # 6) Countplot Graph:
# The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable
#
# # Used for:
# It uses the concept of a bar chart for the visual depiction.

# %%
# Using the inbuit dataset 
data=sns.load_dataset("tips")
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Plotting the Countplot
sns.countplot(data=data,x='day',hue='sex')

plt.show()

# %% [markdown]
# # Visual Insights:
# From the above Countplot we can conclude that,Females visit the resturant less on the weekends compared to Males.

# %%
# Import the Employee dataset 
emp.head(2)
# Out:
#      EEID      Full Name            Job Title Department  \
# 0  E02387    Emily Davis           Sr. Manger         IT
# 1  E04105  Theodore Dinh  Technical Architect         IT
#
#             Business Unit  Gender Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female     Black   55 2016-04-08         141604
# 1           Manufacturing    Male     Asian   59 1997-11-29          99975
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# 1     0.00          China  Chongqing        NaT

# %%
sns.countplot(data=emp,x='Country',hue='Gender',palette="spring")
plt.title("Classification of Gender based on Country")

plt.show()

# %% [markdown]
# # Viusual Insights :
# 1)From the above countplot graph we can conclude that United States rank the highest number of working Employees.
# 2)Also it can be concluded that China ranks equal gender working professionals.

# %% [markdown]
# # 7) Violin Plot:
# A violin plot is a statistical graph that shows the distribution of numerical data for one or more groups
#
# # Used for :
# Violin plots are used to visualize the distribution of numerical data.

# %%
# Importing the Inbuit seaborn dataset
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Plotting the violin  plot

plt.figure(figsize=(12,6))

plt.subplot(2,2,1)
sns.violinplot(data=data,x="total_bill")

plt.subplot(2,2,2)
sns.violinplot(data=data,x="tip")

plt.suptitle("Distribution of Tip and Total Bills ")


plt.show()

# %% [markdown]
# # Visual Insights:
#
# 1)The maximum amounts of bill is between 10 to 20(dollars).
# 2)The maximum tips received is 2 (dollars).

# %%
# Importing the employee dataset 
emp.head(2)
# Out:
#      EEID      Full Name            Job Title Department  \
# 0  E02387    Emily Davis           Sr. Manger         IT
# 1  E04105  Theodore Dinh  Technical Architect         IT
#
#             Business Unit  Gender Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female     Black   55 2016-04-08         141604
# 1           Manufacturing    Male     Asian   59 1997-11-29          99975
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# 1     0.00          China  Chongqing        NaT

# %%
# Plotting the Violin Plot 
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
sns.violinplot(data=emp,x='Bonus %',palette="magma")
plt.title("Distribution of Employees received Bonus")

plt.subplot(2,2,2)
sns.violinplot(data=emp,x='Annual Salary',palette="bright")
plt.title("Distribution of Annual Salary")

plt.show()

# %% [markdown]
# # Visual Insights:
# 1)From the Graph we can conclude that maximum employees havent received any Bonues.
# 2)From the Graph we can conclude that Annual Average Salary of Employees is under 1 Lakh.

# %% [markdown]
# # 8) Pairplot:
# A pair plot, also called a scatterplot matrix, is a matrix of graphs that shows the relationship between each pair of variables in a dataset. It combines scatter plots and histograms to provide a unique overview of the dataset's distributions and correlations
#
# # Used for:
# It's a tool used for exploring relationships and distributions in a dataset

# %%
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Plotting the Pair Plot 

sns.pairplot(data=data,hue='sex')

plt.show()

# %% [markdown]
# # 9) Strip Plot:
# A strip plot is a type of data visualization that shows the distribution of a single-dimensional value. It's also known as a dot plot, individual value plot, or single-axis scatter plot.
#
# # Used for:
# It is used to visualise the distribution of many individual one-dimensional values.

# %%
# Importing the Inbult dataset 

data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Plotting the Strip Plot 

sns.stripplot(data=data,x='day',y='total_bill',hue='sex',dodge=True,jitter=0.1)

plt.legend(bbox_to_anchor=(1,1))

plt.show()

# %% [markdown]
# # Visual Insights:
# From the above Strip Plot it can be concluded that,on Thru and Friday resturant made the less sales compared to weekend.

# %% [markdown]
# # 10) Box Plot :
# A box plot, also known as a box and whisker plot, is a graph that summarizes a set of data.
#
# # Used for:
# Box plots are used to show distributions of numeric data values, especially when you want to compare them between multiple groups

# %%
# Importing the Dataset 
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Plotting the Box pLot 

sns.boxplot(data=data,x='sex',y='total_bill',hue='day',fliersize=4) #fliersize= adjust the size of the outliers.
plt.legend(bbox_to_anchor=(1.2,1)) #This adjust the positon of the label
plt.show()

# %% [markdown]
# # Visual Insights:
# From the above Box Plot we can conclude that, Males and Female's Average count of Bill is under 20(Dollars).

# %% [markdown]
# # 11) Cat Plot(Categorical Plot):
#  These kinds of plots allow us to choose a numerical variable, like age, and plot the distribution of age for each category in a selected categorical variable.
#
# # Used for:
# Categorical plots are used to visualize the distribution of categories within a dataset. They can also be used to compare the representations of data across different plots.

# %%
# importing the Dataset"
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Plotting the Cat Plot:

sns.catplot(data=data,x='sex',y='tip',hue='time',jitter=0.2,dodge=True,kind='violin')
#jitter= it means the dataset points are shifted by the number assigned to jitter
#dodge:It is used to rearrang the dataset values.
#kind: It is used to plot the type of graph
plt.show()

# %% [markdown]
# # Visual Insights:
# From the above Catplot it can be concluded that, Female and Male contributes more during Dinner.

# %%
# Importing the Dataset from Inbuilt :

new_data=sns.load_dataset("exercise")
new_data.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
new_data.dtypes
# Out:
# Unnamed: 0       int64
# id               int64
# diet          category
# pulse            int64
# time          category
# kind          category
# dtype: object

# %%
sns.catplot(data=new_data,x='time',y='pulse',dodge=True,jitter=0.2,hue='diet')
sns.set_style(style='ticks')
plt.show()

# %% [markdown]
# # Visual Insights:
# It can be concluded from the above  Catplot that ,more the time spend over at workout , it increses the pulse.

# %% [markdown]
# # 12) Color Palletes:
# It is used to select diffferent types of color shades.

# %%
sns.palplot(sns.color_palette('viridis'))
plt.show()

# %%
sns.palplot(sns.color_palette('spring'))
plt.show()

# %%
sns.palplot(sns.color_palette('Blues'))
plt.show()

# %%
sns.palplot(sns.color_palette("deep"))

# %% [markdown]
# # 13) Multiple Plots :
# It is used to create different plots at a time .

# %%
# Importing the Dataset 

data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Plotting the Graphs

a=sns.FacetGrid(data,col='time',hue='sex') #col: It is used to create subplots of the graph
a.map(sns.barplot,"day","tip")

plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# # 14) Relational Plots :
# A relational plot is a graphical technique that visualizes the statistical relationship between data points.

# %%
# Importing the dataset

sns.relplot(data=data,x='tip',y='total_bill',col='day',hue='sex',size='smoker')

plt.show()

# %% [markdown]
# # 15) Swarm Plot:
# The Data does not overlap on each other ,like Scatter plot

# %%
# Importing the data 
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Plotting the Swarm Plot:

sns.swarmplot(data=data,x='day',y='total_bill',hue='sex',dodge=True)
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# # 16) KDE Plot (Kernel Density Estimation):
# Here we get the frequency of data in the form of wave.

# %%
# Importing the data 
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
plt.figure(figsize=(10,6))

plt.subplot(2,2,1)
sns.kdeplot(data=data,x='total_bill',hue='day',multiple='stack',palette='deep')

plt.subplot(2,2,2)
sns.kdeplot(data=data,x='total_bill',hue='day',multiple='fill')

plt.show()

# %% [markdown]
# # Visual Insights:
# 1)From the above graphs we can conclude that Sunday contributes the larger area and Thursday contributes the lesser Area.
# 2)Also we can see that Friday contributes the less bill amount.
